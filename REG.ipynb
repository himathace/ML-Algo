# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("student_scores.csv")
data
# Out:
#     hours_studied  exam_score
# 0              10          20
# 1              23          35
# 2              34          42
# 3              38          50
# 4              41          52
# 5              54          58
# 6              65          65
# 7              72          70
# 8              83          78
# 9              95          87
# 10            105          94
# 11            113          98

# %%
plt.scatter(data.hours_studied,data.exam_score)
plt.xlabel("hours")
plt.ylabel("marks")
# Out:
# Text(0, 0.5, 'marks')

# %%
x=np.array(data.hours_studied.values)
x
# Out:
# array([ 10,  23,  34,  38,  41,  54,  65,  72,  83,  95, 105, 113])

# %%
y=np.array(data.exam_score.values)
y
# Out:
# array([20, 35, 42, 50, 52, 58, 65, 70, 78, 87, 94, 98])

# %%
model=LinearRegression()
model.fit(x.reshape((-1,1)),y)
# Out:
# LinearRegression()

# %%
new=np.array([6.2]).reshape((-1,1))
new
# Out:
# array([[6.2]])

# %%
predect=model.predict(new)
predect
# Out:
# array([66.02632309])

# %%
plt.scatter(data.hours_studied,data.exam_score)
m,c=np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %%
m
# Out:
# np.float64(6.94707642893642)

# %%
c
# Out:
# np.float64(22.954449229870804)
