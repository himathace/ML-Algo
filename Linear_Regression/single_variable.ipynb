# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### improt data from csv

# %%
data=pd.read_csv("student_scores.csv")
data
# Out:
#     hours_studied  exam_score
# 0              10          20
# 1              23          35
# 2              34          42
# 3              38          50
# 4              41          52
# 5              54          58
# 6              65          65
# 7              72          70
# 8              83          78
# 9              95          87
# 10            105          94
# 11            113          98

# %% [markdown]
# ### draw diagram using matplotlib

# %%
plt.scatter(data.hours_studied,data.exam_score)
plt.xlabel("hours (independent variable)")
plt.ylabel("marks (dependent varaible)")
# Out:
# Text(0, 0.5, 'marks (dependent varaible)')

# %% [markdown]
# ### create a array for x axis values

# %%
x=np.array(data.hours_studied.values)
x
# Out:
# array([ 10,  23,  34,  38,  41,  54,  65,  72,  83,  95, 105, 113])

# %% [markdown]
# ### create a array for y axis valus

# %%
y=np.array(data.exam_score.values)
y
# Out:
# array([20, 35, 42, 50, 52, 58, 65, 70, 78, 87, 94, 98])

# %% [markdown]
# ### Train Model

# %%
model=LinearRegression()
model.fit(x.reshape((-1,1)),y) # model.fit( x(as 2 dementanal array) , y )
# Out:
# LinearRegression()

# %% [markdown]
# ### Add new value for x

# %%
new=np.array([44]).reshape((-1,1))
new
# Out:
# array([[44]])

# %% [markdown]
# ### predect student marks for given value

# %%
predect=model.predict(new)
predect
# Out:
# array([50.07179494])

# %%
plt.scatter(data.hours_studied,data.exam_score)
m,c=np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %% [markdown]
# ### calculate slope

# %%
m
# Out:
# np.float64(0.722626637539633)

# %% [markdown]
# ### calculate intercept

# %%
c
# Out:
# np.float64(18.27622289028741)

# %%
y_new=m*32+c
y_new
# Out:
# np.float64(41.400275291555666)
